# %%
# %matplotlib inline
from neurodynex3.competing_populations import decision_making

decision_making.sim_decision_making_network()
# Out:
# simulating 480 neurons. Start: Thu Jun  2 13:13:17 2022
# WARNING    Cannot use Cython, a test compilation failed: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/ (DistutilsPlatformError) [brian2.codegen.runtime.cython_rt.cython_rt.failed_compile_test]
# INFO       Cannot use compiled code, falling back to the numpy code generation target. Note that this will likely be slower than using compiled code. Set the code generation to numpy manually to avoid this message:
# prefs.codegen.target = "numpy" [brian2.devices.device.codegen_fallback]
# sim end: Thu Jun  2 13:14:09 2022
# {'rate_monitor_A': <PopulationRateMonitor, recording neurongroup_1>,
#  'spike_monitor_A': <SpikeMonitor, recording from spikemonitor_1>,
#  'voltage_monitor_A': <StateMonitor, recording ['v'] from neurongroup_1>,
#  'idx_monitored_neurons_A': [5,
#   65,
#   60,
#   70,
#   47,
#   14,
#   89,
#   15,
#   7,
#   91,
#   55,
#   27,
#   84,
#   79,
#   4,
#   18,
#   20,
#   38,
#   64,
#   25,
#   71,
#   87,
#   39,
#   23,
#   73,
#   2,
#   31,
#   43,
#   35,
#   80,
#   37,
#   12,
#   46,
#   13,
#   48,
#   40,
#   56,
#   85,
#   68,
#   6,
#   82,
#   21,
#   34,
#   93,
#   86,
#   11,
#   90,
#   72,
#   8,
#   28,
#   45,
#   88,
#   77,
#   50,
#   54,
#   16,
#   92,
#   52,
#   0,
#   76,
#   26,
#   17,
#   66,
#   62,
#   83,
#   3,
#   24,
#   61,
#   78,
#   44,
#   22,
#   94,
#   57,
#   10,
#   74,
#   81,
#   9,
#   30,
#   1,
#   41,
#   29,
#   95,
#   67,
#   19,
#   49,
#   32,
#   51,
#   42,
#   53,
#   36,
#   33,
#   63,
#   69,
#   58,
#   75,
#   59],
#  'rate_monitor_B': <PopulationRateMonitor, recording neurongroup_2>,
#  'spike_monitor_B': <SpikeMonitor, recording from spikemonitor_2>,
#  'voltage_monitor_B': <StateMonitor, recording ['v'] from neurongroup_2>,
#  'idx_monitored_neurons_B': [26,
#   89,
#   83,
#   62,
#   23,
#   48,
#   74,
#   9,
#   87,
#   56,
#   76,
#   39,
#   84,
#   91,
#   44,
#   43,
#   50,
#   68,
#   34,
#   61,
#   79,
#   10,
#   5,
#   73,
#   7,
#   77,
#   85,
#   2,
#   19,
#   21,
#   60,
#   33,
#   14,
#   45,
#   49,
#   20,
#   37,
#   81,
#   86,
#   66,
#   16,
#   59,
#   32,
#   58,
#   25,
#   41,
#   51,
#   71,
#   93,
#   78,
#   12,
#   42,
#   15,
#   46,
#   69,
#   55,
#   3,
#   94,
#   8,
#   65,
#   67,
#   47,
#   29,
#   13,
#   52,
#   22,
#   6,
#   92,
#   28,
#   82,
#   17,
#   35,
#   75,
#   1,
#   27,
#   38,
#   24,
#   90,
#   70,
#   57,
#   40,
#   30,
#   0,
#   88,
#   80,
#   53,
#   18,
#   63,
#   64,
#   95,
#   4,
#   11,
#   72,
#   36,
#   31,
#   54],
#  'rate_monitor_Z': <PopulationRateMonitor, recording neurongroup_3>,
#  'spike_monitor_Z': <SpikeMonitor, recording from spikemonitor_3>,
#  'voltage_monitor_Z': <StateMonitor, recording ['v'] from neurongroup_3>,
#  'idx_monitored_neurons_Z': [100,
#   77,
#   191,
#   55,
#   1,
#   33,
#   185,
#   71,
#   179,
#   189,
#   104,
#   51,
#   65,
#   91,
#   174,
#   74,
#   4,
#   164,
#   141,
#   39,
#   25,
#   24,
#   48,
#   182,
#   124,
#   45,
#   8,
#   80,
#   133,
#   78,
#   62,
#   151,
#   36,
#   144,
#   173,
#   85,
#   89,
#   168,
#   170,
#   41,
#   53,
#   34,
#   103,
#   75,
#   92,
#   119,
#   153,
#   81,
#   154,
#   161,
#   70,
#   135,
#   17,
#   16,
#   157,
#   2,
#   102,
#   131,
#   40,
#   136,
#   155,
#   121,
#   54,
#   159,
#   60,
#   66,
#   128,
#   169,
#   82,
#   19,
#   3,
#   129,
#   187,
#   7,
#   116,
#   132,
#   190,
#   105,
#   21,
#   52,
#   188,
#   112,
#   139,
#   67,
#   163,
#   134,
#   61,
#   38,
#   177,
#   73,
#   107,
#   181,
#   147,
#   35,
#   98,
#   180,
#   145,
#   42,
#   138,
#   31,
#   72,
#   86,
#   27,
#   186,
#   13,
#   6,
#   28,
#   83,
#   15,
#   18,
#   140,
#   37,
#   143,
#   20,
#   122,
#   56,
#   90,
#   93,
#   152,
#   79,
#   172,
#   149,
#   58,
#   148,
#   10,
#   88,
#   125,
#   109,
#   23,
#   160,
#   126,
#   14,
#   64,
#   30,
#   68,
#   59,
#   97,
#   117,
#   158,
#   123,
#   184,
#   176,
#   150,
#   178,
#   118,
#   120,
#   183,
#   96,
#   162,
#   76,
#   111,
#   5,
#   171,
#   166,
#   108,
#   43,
#   165,
#   11,
#   63,
#   57,
#   47,
#   95,
#   94,
#   29,
#   44,
#   114,
#   32,
#   49,
#   110,
#   175,
#   84,
#   87,
#   130,
#   146,
#   69,
#   26,
#   50,
#   167,
#   115,
#   46,
#   113,
#   0,
#   99,
#   156,
#   142,
#   12,
#   22,
#   127,
#   101,
#   106,
#   9,
#   137],
#  'rate_monitor_inhib': <PopulationRateMonitor, recording neurongroup>,
#  'spike_monitor_inhib': <SpikeMonitor, recording from spikemonitor>,
#  'voltage_monitor_inhib': <StateMonitor, recording ['v'] from neurongroup>,
#  'idx_monitored_neurons_inhib': [18,
#   43,
#   40,
#   39,
#   10,
#   58,
#   16,
#   37,
#   91,
#   53,
#   12,
#   41,
#   21,
#   70,
#   33,
#   79,
#   80,
#   63,
#   31,
#   86,
#   94,
#   62,
#   15,
#   48,
#   14,
#   11,
#   49,
#   66,
#   17,
#   68,
#   51,
#   19,
#   85,
#   5,
#   32,
#   73,
#   25,
#   93,
#   74,
#   65,
#   28,
#   75,
#   77,
#   71,
#   4,
#   27,
#   89,
#   1,
#   35,
#   78,
#   45,
#   72,
#   50,
#   87,
#   60,
#   69,
#   13,
#   57,
#   61,
#   26,
#   36,
#   95,
#   81,
#   88,
#   6,
#   67,
#   8,
#   82,
#   44,
#   2,
#   24,
#   23,
#   76,
#   84,
#   29,
#   59,
#   34,
#   56,
#   42,
#   38,
#   83,
#   90,
#   0,
#   46,
#   7,
#   22,
#   3,
#   54,
#   55,
#   64,
#   20,
#   47,
#   52,
#   92,
#   30,
#   9]}

# %%
import brian2 as b2
from brian2 import NeuronGroup, Synapses, PoissonInput, PoissonGroup, network_operation
from brian2.monitors import StateMonitor, SpikeMonitor, PopulationRateMonitor
from random import sample
import numpy.random as rnd
from neurodynex3.tools import plot_tools
import numpy
import matplotlib.pyplot as plt
from math import floor
import time

b2.defaultclock.dt = 0.10 * b2.ms

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.512, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:18:28 2022
# sim end: Thu Jun  2 13:19:58 2022

# %%
results_512 = results

# %%
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()

# %%
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=100. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=100. * b2.ms,
                                 sup_title="Right")

plt.show()

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.128, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:23:53 2022
# sim end: Thu Jun  2 13:25:23 2022

# %%
results_128 = results

# %% [markdown]
# 51.2% 와 12.8% 의 simulation results 를 비교하기 위해서

# %%
results = results_512

plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Left")



results = results_128

plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Left")
# Out:
# (<Figure size 720x288 with 3 Axes>,
#  <AxesSubplot:title={'center':'Raster Plot'}, ylabel='neuron #'>,
#  <AxesSubplot:title={'center':'Population Activity'}, ylabel='A(t) [Hz]'>,
#  <AxesSubplot:title={'center':'Voltage Traces'}, xlabel='t [ms]', ylabel='V(t) [mV]'>)

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.128, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=20. * b2.ms,
                                 sup_title="Right")

plt.show()

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.128, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()

# %% [markdown]
# mu0_mean_stimulus_Hz = 500

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.0, w_pos=2.0, mu0_mean_stimulus_Hz=500 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:29:35 2022
# sim end: Thu Jun  2 13:31:06 2022

# %%
results_0 = results

# %% [markdown]
# mu0_mean_stimulus_Hz = 40
# coherence_level=+0.0

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.0, w_pos=2.0, mu0_mean_stimulus_Hz=40 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:34:14 2022
# sim end: Thu Jun  2 13:35:43 2022

# %%
results_0 = results

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.128, w_pos=2.0, mu0_mean_stimulus_Hz=40 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:38:47 2022
# sim end: Thu Jun  2 13:40:18 2022

# %%
results_128 = results

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.512, w_pos=2.0, mu0_mean_stimulus_Hz=40 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:42:23 2022
# sim end: Thu Jun  2 13:43:54 2022

# %%
results_512 = results

# %% [markdown]
# mu0_mean_stimulus_Hz = 250

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.512, w_pos=2.0, mu0_mean_stimulus_Hz=250 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:46:38 2022
# sim end: Thu Jun  2 13:48:07 2022

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.0, w_pos=2.0, mu0_mean_stimulus_Hz=250 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 14:02:15 2022
# sim end: Thu Jun  2 14:03:46 2022

# %%
results_0 = results

# %% [markdown]
# mu0_mean_stimulus_Hz=250 * b2.Hz 을 이렇게 설정하고,
# coherence level 을 0.128 로 하면 ramping이 coherent level이 0 일 때 보다는 더 빨리 들어

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.128, w_pos=2.0, mu0_mean_stimulus_Hz=250 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 13:53:58 2022
# sim end: Thu Jun  2 13:55:28 2022

# %%
results_128 = results

# %%
"""
A simple example to get started.
Returns:

"""
stim_start = 0. * b2.ms
stim_duration = 1000 * b2.ms
print("stimulus start: {}, stimulus end: {}".format(stim_start, stim_start+stim_duration))

results = decision_making.sim_decision_making_network(N_Excit=341, N_Inhib=85, weight_scaling_factor=6.0,
                                      t_stimulus_start=stim_start, t_stimulus_duration=stim_duration,
                                      coherence_level=+0.512, w_pos=2.0, mu0_mean_stimulus_Hz=250 * b2.Hz,
                                      max_sim_time=2000. * b2.ms)
plot_tools.plot_network_activity(results["rate_monitor_A"], results["spike_monitor_A"],
                                 results["voltage_monitor_A"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Left")
plot_tools.plot_network_activity(results["rate_monitor_B"], results["spike_monitor_B"],
                                 results["voltage_monitor_B"], t_min=0. * b2.ms, avg_window_width=40.1 * b2.ms,
                                 sup_title="Right")

plt.show()
# Out:
# stimulus start: 0.0, stimulus end: 1.0
# simulating 426 neurons. Start: Thu Jun  2 14:05:24 2022
# sim end: Thu Jun  2 14:06:56 2022

# %%
results_512 = results

# %%
import pickle

# %%
total_results = {'results_0':results_0, 'results_128':results_128, 'results_512':results_512}

# %%
type(total_results)
# Out:
# dict

# %%
len(total_results)
# Out:
# 3

# %%
total_results
# Out:
# {'results_0': {'rate_monitor_A': <PopulationRateMonitor, recording neurongroup_21>,
#   'spike_monitor_A': <SpikeMonitor, recording from spikemonitor_21>,
#   'voltage_monitor_A': <StateMonitor, recording ['v'] from neurongroup_21>,
#   'idx_monitored_neurons_A': [75,
#    52,
#    82,
#    8,
#    24,
#    77,
#    29,
#    44,
#    54,
#    68,
#    61,
#    73,
#    22,
#    57,
#    51,
#    2,
#    80,
#    33,
#    23,
#    53,
#    81,
#    79,
#    19,
#    74,
#    72,
#    1,
#    15,
#    45,
#    58,
#    56,
#    43,
#    36,
#    20,
#    66,
#    9,
#    17,
#    37,
#    16,
#    64,
#    62,
#    47,
#    60,
#    13,
#    18,
#    30,
#    35,
#    4,
#    12,
#    42,
#    21,
#    83,
#    31,
#    59,
#    41,
#    6,
#    38,
#    46,
#    50,
#    14,
#    63,
#    40,
#    11,
#    48,
#    84,
#    26,
#    76,
#    78,
#    0,
#    5,
#    65,
#    25,
#    27,
#    34,
#    28,
#    67,
#    71,
#    70,
#    55,
#    32,
#    39,
#    7,
#    3,
#    10,
#    49,
#    69],
#   'rate_monitor_B': <PopulationRateMonitor, recording neurongroup_22>,
#   'spike_monitor_B': <SpikeMonitor, recording from spikemonitor_22>,
#   'voltage_monitor_B': <StateMonitor, recording ['v'] from neurongroup_22>,
#   'idx_monitored_neurons_B': [58,
#    59,
#    9,
#    8,
#    23,
#    72,
#    82,
#    31,
#    10,
#    78,
#    25,
#    11,
#    3,
#    33,
#    42,
#    55,
#    1,
#    50,
#    54,
#    7,
#    79,
#    63,
#    38,
#    17,
#    74,
#    71,
#    65,
#    13,
#    57,
#    43,
#    22,
#    67,
#    0,
#    26,
#    84,
#    80,
#    75,
#    12,
#    36,
#    6,
#    52,
#    20,
#    37,
#    18,
#    61,
#    32,
#    45,
#    28,
#    21,
#    40,
#    14,
#    15,
#    16,
#    83,
#    39,
#    68,
#    81,
#    60,
#    70,
#    64,
#    29,
#    69,
#    66,
#    51,
#    47,
#    19,
#    24,
#    34,
#    76,
#    27,
#    49,
#    46,
#    73,
#    44,
#    30,
#    35,
#    62,
#    5,
#    48,
#    4,
#    53,
#    2,
#    56,
#    77,
#    41],
#   'rate_monitor_Z': <PopulationRateMonitor, recording neurongroup_23>,
#   'spike_monitor_Z': <SpikeMonitor, recording from spikemonitor_23>,
#   'voltage_monitor_Z': <StateMonitor, recording ['v'] from neurongroup_23>,
#   'idx_monitored_neurons_Z': [169,
#    134,
#    25,
#    16,
#    65,
#    71,
#    98,
#    10,
#    79,
#    40,
#    167,
#    90,
#    104,
#    145,
#    101,
#    110,
#    48,
#    102,
#    115,
#    43,
#    45,
#    149,
#    96,
#    89,
#    132,
#    28,
#    27,
#    112,
#    165,
#    150,
#    76,
#    63,
#    84,
#    138,
#    125,
#    126,
#    26,
#    8,
#    53,
#    18,
#    34,
#    54,
#    42,
#    113,
#    36,
#    56,
#    162,
#    70,
#    131,
#    62,
#    97,
#    124,
#    14,
#    85,
#    80,
#    146,
#    32,
#    161,
#    68,
#    47,
#    5,
#    147,
#    50,
#    130,
#    93,
#    57,
#    35,
#    4,
#    15,
#    73,
#    46,
#    109,
#    9,
#    143,
#    7,
#    58,
#    128,
#    6,
#    168,
#    2,
#    3,
#    164,
#    52,
#    66,
#    144,
#    75,
#    136,
#    44,
#    108,
#    51,
#    139,
#    99,
#    12,
#    159,
#    72,
#    106,
#    87,
#    17,
#    158,
#    37,
#    123,
#    69,
#    152,
#    55,
#    88,
#    86,
#    111,
#    1,
#    105,
#    107,
#    78,
#    157,
#    0,
#    29,
#    103,
#    41,
#    11,
#    64,
#    38,
#    81,
#    83,
#    121,
#    59,
#    120,
#    21,
#    30,
#    61,
#    39,
#    129,
#    148,
#    114,
#    166,
#    91,
#    116,
#    154,
#    95,
#    135,
#    94,
#    142,
#    67,
#    49,
#    23,
#    100,
#    118,
#    170,
#    77,
#    33,
#    24,
#    163,
#    155,
#    92,
#    140,
#    133,
#    31,
#    156,
#    60,
#    119,
#    20,
#    127,
#    137,
#    13,
#    74,
#    151,
#    117,
#    22,
#    153,
#    122,
#    141,
#    19,
#    82,
#    160],
#   'rate_monitor_inhib': <PopulationRateMonitor, recording neurongroup_20>,
#   'spike_monitor_inhib': <SpikeMonitor, recording from spikemonitor_20>,
#   'voltage_monitor_inhib': <StateMonitor, recording ['v'] from neurongroup_20>,
#   'idx_monitored_neurons_inhib': [71,
#    76,
#    42,
#    82,
#    2,
#    38,
#    6,
#    79,
#    60,
#    64,
#    10,
#    50,
#    81,
#    19,
#    40,
#    21,
#    47,
#    80,
#    4,
#    46,
#    75,
#    7,
#    36,
#    66,
#    58,
#    0,
#    37,
#    20,
#    59,
#    18,
#    45,
#    23,
#    35,
#    41,
#    83,
#    22,
#    1,
#    32,
#    67,
#    8,
#    48,
#    62,
#    65,
#    12,
#    39,
#    15,
#    43,
#    54,
#    49,
#    78,
#    55,
#    9,
#    33,
#    11,
#    69,
#    24,
#    56,
#    13,
#    5,
#    77,
#    44,
#    30,
#    26,
#    53,
#    14,
#    16,
#    29,
#    72,
#    34,
#    61,
#    31,
#    17,
#    57,
#    70,
#    27,
#    25,
#    68,
#    28,
#    51,
#    3,
#    73,
#    63,
#    84,
#    52,
#    74]},
#  'results_128': {'rate_monitor_A': <PopulationRateMonitor, recording neurongroup_9>,
#   'spike_monitor_A': <SpikeMonitor, recording from spikemonitor_9>,
#   'voltage_monitor_A': <StateMonitor, recording ['v'] from neurongroup_9>,
#   'idx_monitored_neurons_A': [6,
#    56,
#    9,
#    84,
#    41,
#    68,
#    26,
#    4,
#    39,
#    51,
#    35,
#    31,
#    70,
#    0,
#    33,
#    48,
#    21,
#    37,
#    42,
#    75,
#    74,
#    27,
#    76,
#    60,
#    25,
#    22,
#    45,
#    7,
#    11,
#    24,
#    34,
#    19,
#    64,
#    15,
#    57,
#    52,
#    80,
#    49,
#    38,
#    79,
#    30,
#    65,
#    8,
#    59,
#    78,
#    43,
#    18,
#    54,
#    3,
#    61,
#    46,
#    2,
#    71,
#    23,
#    67,
#    83,
#    47,
#    81,
#    58,
#    32,
#    13,
#    5,
#    50,
#    66,
#    82,
#    16,
#    10,
#    28,
#    29,
#    1,
#    77,
#    53,
#    17,
#    20,
#    44,
#    40,
#    69,
#    72,
#    73,
#    55,
#    36,
#    63,
#    62,
#    14,
#    12],
#   'rate_monitor_B': <PopulationRateMonitor, recording neurongroup_10>,
#   'spike_monitor_B': <SpikeMonitor, recording from spikemonitor_10>,
#   'voltage_monitor_B': <StateMonitor, recording ['v'] from neurongroup_10>,
#   'idx_monitored_neurons_B': [78,
#    20,
#    68,
#    28,
#    60,
#    22,
#    43,
#    7,
#    33,
#    37,
#    59,
#    48,
#    30,
#    6,
#    51,
#    77,
#    75,
#    17,
#    14,
#    61,
#    4,
#    25,
#    64,
#    56,
#    84,
#    15,
#    13,
#    24,
#    53,
#    50,
#    34,
#    45,
#    82,
#    26,
#    8,
#    44,
#    27,
#    83,
#    40,
#    72,
#    73,
#    66,
#    58,
#    80,
#    49,
#    54,
#    21,
#    36,
#    74,
#    42,
#    69,
#    46,
#    76,
#    70,
#    63,
#    18,
#    65,
#    32,
#    81,
#    52,
#    39,
#    0,
#    47,
#    71,
#    79,
#    12,
#    3,
#    9,
#    23,
#    62,
#    31,
#    55,
#    67,
#    5,
#    19,
#    41,
#    57,
#    10,
#    2,
#    35,
#    11,
#    1,
#    38,
#    29,
#    16],
#   'rate_monitor_Z': <PopulationRateMonitor, recording neurongroup_11>,
#   'spike_monitor_Z': <SpikeMonitor, recording from spikemonitor_11>,
#   'voltage_monitor_Z': <StateMonitor, recording ['v'] from neurongroup_11>,
#   'idx_monitored_neurons_Z': [83,
#    92,
#    59,
#    25,
#    91,
#    73,
#    94,
#    60,
#    106,
#    137,
#    64,
#    120,
#    30,
#    26,
#    53,
#    124,
#    14,
#    47,
#    23,
#    169,
#    101,
#    129,
#    115,
#    17,
#    35,
#    161,
#    13,
#    70,
#    146,
#    104,
#    116,
#    72,
#    113,
#    11,
#    93,
#    84,
#    155,
#    57,
#    168,
#    143,
#    153,
#    111,
#    89,
#    88,
#    164,
#    3,
#    109,
#    8,
#    145,
#    107,
#    82,
#    122,
#    71,
#    147,
#    170,
#    151,
#    138,
#    24,
#    15,
#    21,
#    50,
#    48,
#    34,
#    46,
#    77,
#    136,
#    167,
#    1,
#    39,
#    66,
#    127,
#    4,
#    85,
#    56,
#    41,
#    9,
#    152,
#    7,
#    119,
#    135,
#    38,
#    108,
#    160,
#    44,
#    86,
#    32,
#    67,
#    81,
#    162,
#    6,
#    166,
#    121,
#    154,
#    69,
#    63,
#    49,
#    148,
#    163,
#    42,
#    68,
#    65,
#    98,
#    43,
#    97,
#    141,
#    96,
#    5,
#    157,
#    61,
#    90,
#    165,
#    100,
#    159,
#    110,
#    128,
#    79,
#    103,
#    134,
#    36,
#    156,
#    29,
#    10,
#    126,
#    12,
#    139,
#    133,
#    142,
#    20,
#    125,
#    16,
#    144,
#    31,
#    112,
#    132,
#    105,
#    99,
#    37,
#    158,
#    74,
#    80,
#    75,
#    54,
#    123,
#    130,
#    117,
#    114,
#    118,
#    22,
#    95,
#    149,
#    131,
#    28,
#    78,
#    45,
#    140,
#    55,
#    18,
#    33,
#    52,
#    51,
#    19,
#    150,
#    58,
#    27,
#    2,
#    102,
#    87,
#    62,
#    40,
#    76,
#    0],
#   'rate_monitor_inhib': <PopulationRateMonitor, recording neurongroup_8>,
#   'spike_monitor_inhib': <SpikeMonitor, recording from spikemonitor_8>,
#   'voltage_monitor_inhib': <StateMonitor, recording ['v'] from neurongroup_8>,
#   'idx_monitored_neurons_inhib': [1,
#    63,
#    75,
#    26,
#    57,
#    38,
#    44,
#    19,
#    29,
#    16,
#    46,
#    34,
#    70,
#    42,
#    20,
#    10,
#    9,
#    81,
#    13,
#    48,
#    30,
#    23,
#    62,
#    18,
#    79,
#    7,
#    40,
#    8,
#    80,
#    41,
#    50,
#    28,
#    22,
#    33,
#    47,
#    61,
#    43,
#    56,
#    32,
#    60,
#    72,
#    74,
#    67,
#    3,
#    51,
#    77,
#    25,
#    65,
#    5,
#    21,
#    84,
#    17,
#    12,
#    73,
#    37,
#    4,
#    64,
#    83,
#    49,
#    11,
#    31,
#    71,
#    82,
#    54,
#    53,
#    59,
#    0,
#    45,
#    68,
#    24,
#    15,
#    39,
#    35,
#    76,
#    6,
#    14,
#    66,
#    36,
#    55,
#    58,
#    2,
#    78,
#    69,
#    52,
#    27]},
#  'results_512': {'rate_monitor_A': <PopulationRateMonitor, recording neurongroup_13>,
#   'spike_monitor_A': <SpikeMonitor, recording from spikemonitor_13>,
#   'voltage_monitor_A': <StateMonitor, recording ['v'] from neurongroup_13>,
#   'idx_monitored_neurons_A': [65,
#    24,
#    8,
#    37,
#    34,
#    44,
#    81,
#    84,
#    68,
#    5,
#    25,
#    36,
#    10,
#    4,
#    71,
#    57,
#    52,
#    61,
#    54,
#    83,
#    58,
#    6,
#    60,
#    50,
#    76,
#    42,
#    43,
#    17,
#    66,
#    48,
#    67,
#    3,
#    35,
#    9,
#    29,
#    0,
#    72,
#    20,
#    64,
#    56,
#    77,
#    63,
#    39,
#    45,
#    49,
#    82,
#    53,
#    55,
#    23,
#    1,
#    79,
#    47,
#    22,
#    32,
#    46,
#    30,
#    51,
#    27,
#    26,
#    18,
#    70,
#    13,
#    80,
#    12,
#    21,
#    69,
#    78,
#    2,
#    62,
#    19,
#    41,
#    59,
#    31,
#    73,
#    40,
#    11,
#    74,
#    16,
#    28,
#    15,
#    75,
#    38,
#    7,
#    33,
#    14],
#   'rate_monitor_B': <PopulationRateMonitor, recording neurongroup_14>,
#   'spike_monitor_B': <SpikeMonitor, recording from spikemonitor_14>,
#   'voltage_monitor_B': <StateMonitor, recording ['v'] from neurongroup_14>,
#   'idx_monitored_neurons_B': [52,
#    18,
#    29,
#    61,
#    11,
#    83,
#    39,
#    21,
#    16,
#    5,
#    76,
#    53,
#    74,
#    17,
#    55,
#    13,
#    72,
#    79,
#    66,
#    68,
#    19,
#    30,
#    44,
#    27,
#    75,
#    8,
#    63,
#    38,
#    12,
#    4,
#    0,
#    62,
#    70,
#    58,
#    23,
#    9,
#    47,
#    65,
#    28,
#    49,
#    48,
#    54,
#    22,
#    10,
#    24,
#    25,
#    46,
#    81,
#    20,
#    69,
#    77,
#    3,
#    43,
#    50,
#    33,
#    31,
#    82,
#    64,
#    60,
#    2,
#    36,
#    80,
#    67,
#    7,
#    1,
#    84,
#    42,
#    45,
#    41,
#    56,
#    32,
#    57,
#    14,
#    6,
#    51,
#    26,
#    35,
#    15,
#    71,
#    37,
#    34,
#    78,
#    40,
#    73,
#    59],
#   'rate_monitor_Z': <PopulationRateMonitor, recording neurongroup_15>,
#   'spike_monitor_Z': <SpikeMonitor, recording from spikemonitor_15>,
#   'voltage_monitor_Z': <StateMonitor, recording ['v'] from neurongroup_15>,
#   'idx_monitored_neurons_Z': [115,
#    121,
#    35,
#    136,
#    80,
#    170,
#    3,
#    155,
#    70,
#    7,
#    113,
#    145,
#    23,
#    135,
#    58,
#    13,
#    144,
#    119,
#    55,
#    59,
#    118,
#    17,
#    114,
#    47,
#    6,
#    117,
#    61,
#    52,
#    32,
#    94,
#    26,
#    51,
#    91,
#    33,
#    89,
#    40,
#    92,
#    12,
#    98,
#    102,
#    63,
#    0,
#    21,
#    140,
#    99,
#    95,
#    38,
#    153,
#    131,
#    73,
#    79,
#    71,
#    69,
#    104,
#    138,
#    54,
#    10,
#    24,
#    2,
#    161,
#    66,
#    65,
#    127,
#    147,
#    75,
#    123,
#    141,
#    46,
#    85,
#    109,
#    160,
#    31,
#    163,
#    83,
#    20,
#    15,
#    41,
#    11,
#    157,
#    116,
#    82,
#    29,
#    159,
#    64,
#    142,
#    76,
#    148,
#    48,
#    129,
#    42,
#    5,
#    36,
#    57,
#    107,
#    18,
#    143,
#    78,
#    53,
#    125,
#    90,
#    162,
#    45,
#    68,
#    112,
#    74,
#    39,
#    151,
#    137,
#    81,
#    49,
#    168,
#    154,
#    28,
#    77,
#    96,
#    27,
#    130,
#    134,
#    146,
#    111,
#    22,
#    169,
#    43,
#    167,
#    166,
#    132,
#    56,
#    25,
#    126,
#    110,
#    97,
#    44,
#    124,
#    164,
#    50,
#    34,
#    108,
#    128,
#    158,
#    100,
#    122,
#    93,
#    72,
#    62,
#    101,
#    16,
#    87,
#    105,
#    86,
#    103,
#    88,
#    156,
#    4,
#    84,
#    120,
#    8,
#    37,
#    67,
#    60,
#    9,
#    149,
#    139,
#    152,
#    106,
#    165,
#    150,
#    1,
#    14,
#    30,
#    19,
#    133],
#   'rate_monitor_inhib': <PopulationRateMonitor, recording neurongroup_12>,
#   'spike_monitor_inhib': <SpikeMonitor, recording from spikemonitor_12>,
#   'voltage_monitor_inhib': <StateMonitor, recording ['v'] from neurongroup_12>,
#   'idx_monitored_neurons_inhib': [71,
#    23,
#    81,
#    10,
#    76,
#    48,
#    1,
#    57,
#    33,
#    26,
#    82,
#    30,
#    60,
#    83,
#    55,
#    40,
#    46,
#    67,
#    44,
#    0,
#    41,
#    9,
#    6,
#    17,
#    39,
#    4,
#    18,
#    3,
#    53,
#    37,
#    5,
#    29,
#    77,
#    75,
#    62,
#    49,
#    43,
#    2,
#    78,
#    25,
#    59,
#    80,
#    61,
#    31,
#    36,
#    45,
#    69,
#    19,
#    15,
#    47,
#    54,
#    13,
#    8,
#    50,
#    7,
#    42,
#    27,
#    16,
#    63,
#    73,
#    51,
#    28,
#    35,
#    21,
#    12,
#    84,
#    52,
#    11,
#    32,
#    58,
#    38,
#    68,
#    72,
#    20,
#    66,
#    34,
#    56,
#    65,
#    70,
#    22,
#    74,
#    14,
#    79,
#    64,
#    24]}}

# %%
plot_tools.plot_network_activity(results_512["rate_monitor_inhib"], results_512["spike_monitor_inhib"],
                                 results_512["voltage_monitor_inhib"], t_min=0. * b2.ms, avg_window_width=100.1 * b2.ms,
                                 sup_title="Right")
# Out:
# (<Figure size 720x288 with 3 Axes>,
#  <AxesSubplot:title={'center':'Raster Plot'}, ylabel='neuron #'>,
#  <AxesSubplot:title={'center':'Population Activity'}, ylabel='A(t) [Hz]'>,
#  <AxesSubplot:title={'center':'Voltage Traces'}, xlabel='t [ms]', ylabel='V(t) [mV]'>)

# %%
plot_tools.plot_network_activity(results_128["rate_monitor_inhib"], results_128["spike_monitor_inhib"],
                                 results_128["voltage_monitor_inhib"], t_min=0. * b2.ms, avg_window_width=100.1 * b2.ms,
                                 sup_title="Right")
# Out:
# (<Figure size 720x288 with 3 Axes>,
#  <AxesSubplot:title={'center':'Raster Plot'}, ylabel='neuron #'>,
#  <AxesSubplot:title={'center':'Population Activity'}, ylabel='A(t) [Hz]'>,
#  <AxesSubplot:title={'center':'Voltage Traces'}, xlabel='t [ms]', ylabel='V(t) [mV]'>)

# %%
plot_tools.plot_network_activity(results_0["rate_monitor_inhib"], results_0["spike_monitor_inhib"],
                                 results_0["voltage_monitor_inhib"], t_min=0. * b2.ms, avg_window_width=100.1 * b2.ms,
                                 sup_title="Right")
# Out:
# (<Figure size 720x288 with 3 Axes>,
#  <AxesSubplot:title={'center':'Raster Plot'}, ylabel='neuron #'>,
#  <AxesSubplot:title={'center':'Population Activity'}, ylabel='A(t) [Hz]'>,
#  <AxesSubplot:title={'center':'Voltage Traces'}, xlabel='t [ms]', ylabel='V(t) [mV]'>)

# %%
a = results["rate_monitor_inhib"]

# %%
rate_monitor_inhib

# %% [markdown]
# 모든 세 경우를

# %%
results.keys()
# Out:
# dict_keys(['rate_monitor_A', 'spike_monitor_A', 'voltage_monitor_A', 'idx_monitored_neurons_A', 'rate_monitor_B', 'spike_monitor_B', 'voltage_monitor_B', 'idx_monitored_neurons_B', 'rate_monitor_Z', 'spike_monitor_Z', 'voltage_monitor_Z', 'idx_monitored_neurons_Z', 'rate_monitor_inhib', 'spike_monitor_inhib', 'voltage_monitor_inhib', 'idx_monitored_neurons_inhib'])

# %%
with open('state_mon.pickle', 'w') as f:
    pickle.dump(a, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
#       1 with open('state_mon.pickle', 'w') as f:
# ----> 2     pickle.dump(a, f)
#
# TypeError: cannot pickle 'weakref' object

# %%
rate_monitor =  results_512['rate_monitor_inhib']

# %%
window_width = 100.1 * b2.ms

# %%
ax_rate = None

# %%
(ax_rate) = plt.plot(figsize=(10,4))

# %%
ts = rate_monitor.t / b2.ms
idx_rate = (ts >= t_min) & (ts <= t_max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 2>()
#       1 ts = rate_monitor.t / b2.ms
# ----> 2 idx_rate = (ts >= None) & (ts <= None)
#
# TypeError: '>=' not supported between instances of 'float' and 'NoneType'

# %%
t_max = max(rate_monitor.t / b2.ms)

# %%
t_max
# Out:
# 1999.8999999999999

# %%
t_min = max(0., t_max - 100.)  # if none, plot at most the last 100ms

# %%
t_min
# Out:
# 1899.8999999999999

# %%
# get a reasonable default interval
if t_max is None:
    t_max = max(rate_monitor.t / b2.ms)
else:
    t_max = t_max / b2.ms
if t_min is None:
    t_min = max(0., t_max - 100.)  # if none, plot at most the last 100ms
else:
    t_min = t_min / b2.ms

# %%
t_max = max(rate_monitor.t / b2.ms)

# %%
t_max  = 500

# %%
t_min = max(0., t_max - 100.)  # if none, plot at most the last 100ms

# %%
t_min = 0

# %%
ts = rate_monitor.t / b2.ms

# %%
len(ts)
# Out:
# 20000

# %%
t_min = 0

# %%
idx_rate = (ts >= t_min) & (ts <= t_max)

# %%
len(idx_rate)
# Out:
# 20000

# %%
window_width
# Out:
# 100.1 * msecond

# %%
smoothed_rates = rate_monitor.smooth_rate(window="flat", width=window_width)/b2.Hz

# %%
len(smoothed_rates)
# Out:
# 20000

# %%
plt.plot(ts[idx_rate], smoothed_rates[idx_rate])

# %%
plt.plot(ts[idx_rate], smoothed_rates[idx_rate])

# %%
window_width
# Out:
# 100.1 * msecond

# %%
def plot_population_activity(window_width=0.5*b2.ms):
    """
    Helper. Plots the population rate and a mean
    """
    ts = rate_monitor.t / b2.ms
    idx_rate = (ts >= t_min) & (ts <= t_max)
    # ax_rate.plot(ts[idx_rate],rate_monitor.rate[idx_rate]/b2.Hz, ".k", markersize=2)
    smoothed_rates = rate_monitor.smooth_rate(window="flat", width=window_width)/b2.Hz
    ax_rate.plot(ts[idx_rate], smoothed_rates[idx_rate])
    ax_rate.set_ylabel("A(t) [Hz]")
    ax_rate.set_title("Population Activity", fontsize=10)

# %%
smoothed_rates = rate_monitor.smooth_rate(window="flat", width=window_width)/b2.Hz
ax_rate.plot(ts[idx_rate], smoothed_rates[idx_rate])
ax_rate.set_ylabel("A(t) [Hz]")
ax_rate.set_title("Population Activity", fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [98], in <cell line: 2>()
#       1 smoothed_rates = rate_monitor.smooth_rate(window="flat", width=window_width)/b2.Hz
# ----> 2 ax_rate.plot(ts[idx_rate], smoothed_rates[idx_rate])
#       3 ax_rate.set_ylabel("A(t) [Hz]")
#       4 ax_rate.set_title("Population Activity", fontsize=10)
#
# NameError: name 'ts' is not defined

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (7, 4)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()



rate_monitor_512 =  results_512['rate_monitor_inhib']
rate_monitor_128 =  results_128['rate_monitor_inhib']

rate_monitor_0 =  results_0['rate_monitor_inhib']

window_width = 150.1 * b2.ms
(ax_rate) = plt.plot(figsize=(10,4))
t_max  = 1500
t_min = 0 
ts = rate_monitor.t / b2.ms
idx_rate = (ts >= t_min) & (ts <= t_max)
smoothed_rates_512 = rate_monitor_512.smooth_rate(window="flat", width=window_width)/b2.Hz
smoothed_rates_0 = rate_monitor_0.smooth_rate(window="flat", width=window_width)/b2.Hz
smoothed_rates_128 = rate_monitor_128.smooth_rate(window="flat", width=window_width)/b2.Hz

plt.plot(ts[idx_rate], smoothed_rates_512[idx_rate])
#plt.plot(ts[idx_rate], smoothed_rates_128[idx_rate])
plt.plot(ts[idx_rate], smoothed_rates_0[idx_rate])

plt.xlabel('Time (ms)')
plt.ylabel('Averaged Firing Rate (spikes/s)')

labels= ["51.2%","0%"]

plt.legend(labels)
#ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)        # 왼쪽 축을 가운데 위치로 이동
ax.spines['right'].set_visible(False)  


plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (7, 4)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()


rate_monitor_512 =  results_512['rate_monitor_inhib']
rate_monitor_128 =  results_128['rate_monitor_inhib']

rate_monitor_0 =  results_0['rate_monitor_inhib']

window_width = 150.1 * b2.ms
(ax_rate) = plt.plot(figsize=(10,4))
t_max  = 1500
t_min = 0 
ts = rate_monitor.t / b2.ms
idx_rate = (ts >= t_min) & (ts <= t_max)
smoothed_rates_512 = rate_monitor_512.smooth_rate(window="flat", width=window_width)/b2.Hz
smoothed_rates_0 = rate_monitor_0.smooth_rate(window="flat", width=window_width)/b2.Hz
smoothed_rates_128 = rate_monitor_128.smooth_rate(window="flat", width=window_width)/b2.Hz

plt.plot(ts[idx_rate], smoothed_rates_512[idx_rate])
plt.plot(ts[idx_rate], smoothed_rates_128[idx_rate])
plt.plot(ts[idx_rate], smoothed_rates_0[idx_rate])

plt.xlabel('Time (ms)')
plt.ylabel('Averaged Firing Rate (spikes/s)')

labels= ["51.2%","12.8%", "0%"]

plt.legend(labels)


#ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)        # 왼쪽 축을 가운데 위치로 이동
ax.spines['right'].set_visible(False)  

plt.show()
